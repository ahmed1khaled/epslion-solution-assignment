# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.2)

# %%
df = pd.read_csv('50ulke.csv')
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %% [markdown]
# numarical data

# %% [markdown]
# univariate

# %%
df['Growth'].hist()

# %% [markdown]
# الداتا متمركزه من 1 الي 2.8

# %%
sns.kdeplot(df['Growth'])

# %% [markdown]
# binomial distripution

# %%
df['National Income'].hist()

# %% [markdown]
# out liyer in 12500 to 14000 and 18500 to 20200

# %%
sns.kdeplot(df['National Income'])

# %% [markdown]
# right skewness

# %% [markdown]
# thare are out liyer in df['National Income'] >1600

# %%
sns.kdeplot(df['Per person'])

# %% [markdown]
# binomial distripution

# %% [markdown]
# Bivariate

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
sns.regplot(x=df['Growth'],y=df['National Income'])

# %% [markdown]
# الدتا متمركزه  من  0 الي 2500

# %% [markdown]
# outliyer df>2500

# %%
sns.regplot(x=df['Per person'],y=df['National Income'])

# %% [markdown]
# الداتا متمركزه من 0 الي 2500

# %% [markdown]
#  not liner corr

# %% [markdown]
# outliyer in df>5000

# %%
sns.regplot(x=df['Growth'],y=df['Per person'])

# %% [markdown]
# not liner corr

# %%
sns.regplot(x=df['Per person'],y=df['Growth'])

# %% [markdown]
# not liner corr

# %%
sns.jointplot(y='Growth', x='National Income', data=df, color='m', height=8, ratio=6)

# %% [markdown]
# outliyer in df>7500

# %%
sns.jointplot(y='Per person', x='National Income', data=df, color='m', height=8, ratio=6)

# %% [markdown]
# من الشكلين متمركزه من 0 الي 2500

# %% [markdown]
# outliyer in df>7500

# %%
sns.jointplot(x='Growth', y='Per person', data=df, color='m', height=8, ratio=6)

# %% [markdown]
# الداتا متمركزه من 1 الي 3

# %%
sns.pairplot(df,hue='Continent')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,hue='Continent',diag_kind='kde')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# national income الدتا متمركزه من 0  الي 25000 مع الكل
# growhh الدتا متمركزه من 0  الي 10
# per person الدتا متمركزه من 0  الي 100000

# %% [markdown]
# categorrical data

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %% [markdown]
# categorrical distribution plots

# %%
sns.boxplot(x='Continent',y='National Income',data=df)

# %% [markdown]
# North America اكتر دخل قومي فيهم
# Europe تليها

# %% [markdown]
# thare are outliyer

# %%
sns.boxplot(x='Continent',y='Per person',data=df)

# %% [markdown]
# North America  فيهمperpersonاكتر  Europe تليها

# %%
sns.boxplot(x='Continent',y='Growth',data=df)

# %% [markdown]
# اسيا اكبرهم تليها اوربا

# %% [markdown]
# out luyer من 7 الي 8

# %% [markdown]
#   national income كلما زاد per person كلما زاد

# %% [markdown]
# boxplot وضح لينا out layer

# %%
sns.boxplot(y='Countries',x='National Income',data=df)

# %%
sns.boxplot(y='Countries',x='Growth',data=df)

# %%
sns.boxplot(y='Countries',x='Per person',data=df)

# %%
sns.violinplot(x='Continent',y='Growth',data=df)

# %% [markdown]
# شمال امريكا الدتا بتاع النمو متمركزه من 2 الي 3 واسيا من 2 الي 7 واوربا من 1 الي  5 وجنوب امريكا من 1 اي 3 وافريقيا من 1 الي 4.2

# %%
sns.violinplot(x='Continent',y='National Income',data=df)

# %%
sns.violinplot(x='Continent',y='Per person',data=df)

# %% [markdown]
# امريكا الدتا متمركزه من 20000 الي 65000 واسيا من 0 الي 20000 واوربا من 0 الي 55000 وجنوب امريكا من 5000 الي 15000وافريقيا من 0 الي 5000

# %%
sns.stripplot(x='Continent',y='Growth',data=df)

# %% [markdown]
# اسيا من 3 الي 4 وشمال امريكا من 2 الي 2.4 واوربا من 1 الي 3 وجنوب امريكا من 1 الي 3

# %% [markdown]
# الداتا متمركزه من 1 الي 4

# %%
sns.stripplot(x='Continent',y='National Income',data=df)

# %% [markdown]
#  اغلبيه الداتا من 0 الي 2000

# %% [markdown]
# outliyer df>12500

# %%
sns.stripplot(x='Continent',y='Per person',data=df)

# %%
sns.swarmplot(x='Continent',y='Growth',data=df)

# %% [markdown]
# اغلبيه الداتا من 1 الي 4.5

# %%
sns.swarmplot(x='Continent',y='National Income',data=df)

# %% [markdown]
# الداتا متمركزه من 0 الي 2500

# %%
sns.swarmplot(x='Continent',y='Per person',data=df)

# %%
sns.barplot(x='Continent',y='Growth',data=df)

# %% [markdown]
#  mean() النمو بتاع اسيا هو الاكبر والشرطه بدل علي

# %%
sns.barplot(x='Continent',y='National Income',data=df)

# %% [markdown]
# شمال امريكا هو الاكبر من الدخل القومي

# %%
sns.barplot(x='Continent',y='Per person',data=df)

# %% [markdown]
# per person اوكرانيا هي الاكبر في

# %%
sns.countplot(df['Continent'])

# %% [markdown]
# اوربا واسيا عددهم قد بعض واكبرهم عدد

# %%
df.corr()
# Out:
#                  Unnamed: 0  National Income    Growth  Per person
# Unnamed: 0         1.000000        -0.549732  0.261063   -0.273373
# National Income   -0.549732         1.000000  0.008961    0.159121
# Growth             0.261063         0.008961  1.000000   -0.252786
# Per person        -0.273373         0.159121 -0.252786    1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.lmplot(x="Per person", y="Growth", data=df, height=7, aspect=1.3)

# %%
sns.lmplot(x="Per person", y="National Income", data=df, height=7, aspect=1.3)

# %%
sns.lmplot(x="Growth", y="National Income", data=df, height=7, aspect=1.3)

# %% [markdown]
# "National Income" and "Per person" are important cloumns
